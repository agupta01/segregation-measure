# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import shapely
from shapely.geometry import Point, Polygon, MultiPolygon
from tqdm import tqdm
import descartes
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import repeat
# %matplotlib inline

# %% [markdown]
# # Demo of the crosswalk generation for redlined districts -> 1940 tracts on Manhattan
# **Purpose of this crosswalk: two-fold, we (a) need a way to characterize the size of the redlined districts, so we use the number of 1940 tracts they fit into as that measure, and (b) when we're computing entropy, we need to know which district each 1940 tract belonged to.**
# Steps are as follows:
# 1. grab data from shapefiles and preprocess them so each district has a corresponding Polygon, each tract has a corresponding Polygon, and both dataframes are on the same projection
# 2. go throuh each 1940 tract and assess it's % area overlap with each district. If the total amount of overlap is > 50%, then we assign that tract to the district it is most in overlap with. NOTE: districts can have more than one 1940 tract, that's kind of the purpose of this exercise

# %%
nyc_rl_map = gpd.read_file("data/redlining-maps/NYManhattan1937.geojson")
nyc_rl_map
# Out:
#     name holc_id holc_grade  \
# 0   None      A1          A
# 1   None      A2          A
# 2   None      A3          A
# 3   None      A4          A
# 4   None      A5          A
# 5   None      A6          A
# 6   None      A7          A
# 7   None      A8          A
# 8   None      B1          B
# 9   None     B10          B
# 10  None     B11          B
# 11  None     B12          B
# 12  None      B2          B
# 13  None      B3          B
# 14  None      B4          B
# 15  None      B5          B
# 16  None      B6          B
# 17  None      B7          B
# 18  None      B8          B
# 19  None      B9          B
# 20  None      C1          C
# 21  None      C2          C
# 22  None      C3          C
# 23  None      C4          C
# 24  None      C5          C
# 25  None      C6          C
# 26  None      D1          D
# 27  None     D10          D
# 28  None     D11          D
# 29  None     D12          D
# 30  None     D13          D
# 31  None     D14          D
# ...

# %%
tracts_1940 = gpd.read_file("data/nhgis0004_shape/nhgis0004_shapefile_tl2008_us_tract_1940/US_tract_1940_conflated.shp")
tracts_1940
# Out:
#      PREFIX  TRACT SUFFIX        GISJOIN    AREA_UNCLI STATE COUNTY AGGPREFIX  \
# 0      None    100   None   G01007300001  1.749567e+06    01    073      None
# 1      None    200   None   G01007300002  1.554529e+06    01    073      None
# 2      None    300   None   G01007300003  3.060810e+06    01    073      None
# 3      None    400   None   G01007300004  3.426404e+06    01    073      None
# 4      None    500   None   G01007300005  3.240566e+06    01    073      None
# ...     ...    ...    ...            ...           ...   ...    ...       ...
# 7558      M   1500   None  G1550095M0015  3.234958e+08    15    009      None
# 7559      M   1600   None  G1550095M0016  9.072801e+08    15    009      None
# 7560      M   1700   None  G1550095M0017  7.932966e+08    15    009      None
# 7561      M   1800   None  G1550095M0018  7.202629e+08    15    009      None
# 7562      M   1900   None  G1550095M0019  1.355606e+08    15    009      None
#
# ...

# %%
nyc_1940 = tracts_1940.loc[(tracts_1940.STATE == '36') & (tracts_1940.COUNTY == '061')]
nyc_1940 = nyc_1940.filter(['GISJOIN', 'geometry'])
type(nyc_1940.loc[4870].geometry) == shapely.geometry.multipolygon.MultiPolygon
nyc_1940['polygonized'] = [shapely.ops.unary_union(x)[0] if type(x) == shapely.geometry.multipolygon.MultiPolygon 
                           else x 
                           for x in nyc_1940.geometry.values]
nyc_1940.crs
# Out:
# <Projected CRS: ESRI:102003>
# Name: USA_Contiguous_Albers_Equal_Area_Conic
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# put the redlining map into the projection of the 1940 tracts
nyc_rl_map = nyc_rl_map.to_crs(nyc_1940.crs)
nyc_rl_map.plot()

# %%
# determines what % of polygon a is inside polygon b
def area_overlap(a, b):
    try:
        return a.intersection(b).area / a.area
    except:
        return 0

# %%
crosswalk_1940 = pd.DataFrame({'holc_id': nyc_rl_map.holc_id,
                                'tract_id_1940': [[] for i in range(len(nyc_rl_map.holc_id))]})
crosswalk_1940.set_index('holc_id', inplace=True)
for i in tqdm(nyc_1940.index): # iterate through the 1940 tracts
    # for each 1940 tract, see it's overlap with each holc_id
    overlaps = np.array(list(map(area_overlap, repeat(nyc_1940.loc[i].polygonized), nyc_rl_map.geometry.values)))
    if sum(overlaps) > 0.5:
        max_district = nyc_rl_map.loc[np.argmax(overlaps)].holc_id
        print(max_district)
        crosswalk_1940.loc[max_district].tract_id_1940.append(nyc_1940.loc[i].GISJOIN[1:])
crosswalk_1940['district_size'] = list(map(len, crosswalk_1940.tract_id_1940.values))
crosswalk_1940
# Out:
#  31%|███       | 29/93 [00:00<00:00, 138.57it/s]
# B10
# B11
# A8
# B9
# C6
# C6
# B8
# B8
# D27
# D27
# D26
# D26
# D26
# D26
# D26
# D26
# D22
# D23
# D24
# D25
# B7
# D23
# D20
# D19
# D19
# B6
# C4
# D21
# D20
#  63%|██████▎   | 59/93 [00:00<00:00, 142.59it/s]
# B6
# D20
# D20
# D19
# B6
# B4
# C4
# C3
# D18
# B4
# B4
# A6
# D17
# D17
# D13
# A3
# D17
# D17
# D16
# D10
# D10
# D15
# D12
# D10
# D9
# 100%|██████████| 93/93 [00:00<00:00, 149.07it/s]
# D11
# D5
# D8
# D6
# C1
# D3
# C1
# D3
# D3
# D3
# D2
# D2
# D3
# D3
# D2
# D1
# D1
# D1
# D1
# D1
#                                              tract_id_1940  district_size
# holc_id
# A1                                                      []              0
# A2                                                      []              0
# A3                                         [3600610004100]              1
# A4                                                      []              0
# ...

# %% [markdown]
# Now that we know which 1940 tracts "belong" to which districts, we can figure out the relative sizes of the districts. This'll be helpful for the constellation -> map process, where we have to figure out how often to "cut the snake" (the cut lengths will mimic the distribution of the kde plot below)

# %%
districts_with_similarity = np.round(len(crosswalk_1940.loc[crosswalk_1940.district_size > 0].index) / len(crosswalk_1940.index),3)
print(f"For NYC, {districts_with_similarity * 100}% districts had one or more matching 1940 tracts.")
sns.kdeplot(crosswalk_1940.loc[(crosswalk_1940.district_size > 0)].sort_values('district_size', ascending=False).district_size)
# Out:
# For NYC, 71.7% districts had one or more matching 1940 tracts.

# %% [markdown]
# # Future steps
# - [ ] repeat for the rest of the cities!

# %% [markdown]
# # Rest of the Cities

# %%
# function to polygonize a geometry list
polygonize = lambda s: [shapely.ops.unary_union(x) if type(x) == shapely.geometry.multipolygon.MultiPolygon 
                           else x 
                           for x in s.values]

# get map filepath data
MAP_FILEPATH = "data/redlining-maps/" 
cities = pd.read_csv("data/redlining-maps/mapmanifest.csv", dtype={'state':str, 'county':str})
cities
# Out:
#            city                    filename state county
# 0       Oakland       CAOakland1937.geojson    06    001
# 1       Atlanta       GAAtlanta1938.geojson    13    121
# 2       Chicago       ILChicago1940.geojson    17    031
# 3     Baltimore     MDBaltimore1937.geojson    24    510
# 4       Detroit       MIDetroit1939.geojson    26    163
# 5         Bronx         NYBronx1938.geojson    36    005
# 6      Brooklyn      NYBrooklyn1938.geojson    36    047
# 7     Manhattan     NYManhattan1937.geojson    36    061
# 8        Queens        NYQueens1938.geojson    36    081
# 9  Philadelphia  PAPhiladelphia1937.geojson    42    101

# %% [markdown]
# ## Oakland

# %%
# get map and census data
city_filename = str(cities[cities.city == 'Oakland'].filename.values[0])
print(city_filename)
oakland_map = gpd.read_file(MAP_FILEPATH + city_filename)
oakland_1940 = tracts_1940.loc[(tracts_1940.STATE == '06') & (tracts_1940.COUNTY == '001')]
# match crs to tract map
oakland_map = oakland_map.to_crs(oakland_1940.crs)
oakland_map['polygonized'] = polygonize(oakland_map.geometry)

oakland_1940 = oakland_1940.filter(['GISJOIN', 'geometry'])
oakland_1940['polygonized'] = polygonize(oakland_1940.geometry)



oakland_map.plot()
oakland_map.head()
# Out:
# CAOakland1937.geojson
#    name holc_id holc_grade                              area_description_data  \
# 0  None       A          A                                           {'': ''}
# 1  None      A1          A  {'1': 'Berkeley Green A-1', '2': 'Characterize...
# 2  None     A10          A  {'1': 'Oakland, California Low Green A-10', '2...
# 3  None     A11          A  {'1': 'Oakland, California Green A-11', '2': '...
# 4  None      A2          A  {'1': 'Berkeley, California Green A-2', '2': '...
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-2256129.507 347868.643, -2256...
# 1  MULTIPOLYGON (((-2258485.842 358951.346, -2258...
# 2  MULTIPOLYGON (((-2258903.862 348155.982, -2258...
# 3  MULTIPOLYGON (((-2256129.507 347868.643, -2256...
# 4  MULTIPOLYGON (((-2259866.693 358959.447, -2259...
#
#                                          polygonized
# 0  POLYGON ((-2256129.507046321 347868.643275286,...
# ...

# %%
def generate_crosswalk(city_name, rl_map, tract_map):
    """
    Returns a crosswalk of 1940 tract_ids in each redlined district.
    """
    crosswalk = pd.DataFrame({'holc_id_uq': ['{}{}'.format(*t) for t in zip(rl_map.holc_grade, rl_map.index)],
                              'tract_id_1940': [[] for i in range(len(rl_map.index))]})
    crosswalk.set_index('holc_id_uq', inplace=True)
    rl_geometries = rl_map.polygonized.values
    for i in tqdm(tract_map.index): # iterate through the 1940 tracts
        # for each 1940 tract, see it's overlap with each holc_id
        overlaps = [area_overlap(tract_map.loc[i].polygonized, g) for g in rl_geometries]
        if sum(overlaps) > 0.5:
            max_district_id = f'{rl_map.loc[np.argmax(overlaps)].holc_grade}{np.argmax(overlaps)}'
            crosswalk.loc[max_district_id].tract_id_1940.append(tract_map.loc[i].GISJOIN[1:])
    crosswalk['district_size'] = list(map(len, crosswalk.tract_id_1940.values))
    
    # summarize
    districts_with_similarity = np.round(
        len(crosswalk.loc[crosswalk.district_size > 0].index) / len(crosswalk.index),3)
    print(f"For {city_name}, {districts_with_similarity * 100}% districts had one or more matching 1940 tracts.")
    sns.kdeplot(crosswalk.loc[(crosswalk.district_size > 0)].sort_values('district_size', ascending=False).district_size)
    return crosswalk

# %%
cw = generate_crosswalk('Oakland', oakland_map, oakland_1940)
cw
# Out:
# 100%|██████████| 117/117 [00:04<00:00, 28.99it/s]
# For Oakland, 53.800000000000004% districts had one or more matching 1940 tracts.
#                                       tract_id_1940  district_size
# holc_id_uq
# A0                       [06000100041, 06000100042]              2
# A1                     [06000100006C, 06000100006D]              2
# A2                                               []              0
# A3                                               []              0
# A4                                               []              0
# ...                                             ...            ...
# D114                                             []              0
# D115                                [0600010AC0006]              1
# D116        [06000100006, 06000100007, 06000100008]              3
# D117                     [06000100014, 06000100016]              2
# D118                     [06000100017, 06000100018]              2
#
# ...

# %%
fig, ax = plt.subplots()
ax.plot(*oakland_1940.loc[(oakland_1940.GISJOIN == 'G06000100041')].polygonized.values[0].exterior.xy, c='r')
ax.scatter(*oakland_1940.loc[(oakland_1940.GISJOIN == 'G06000100041')].polygonized.values[0].centroid.xy, c='black')
ax.plot(*oakland_1940.loc[(oakland_1940.GISJOIN == 'G06000100042')].polygonized.values[0].exterior.xy, c='r')
ax.scatter(*oakland_1940.loc[(oakland_1940.GISJOIN == 'G06000100042')].polygonized.values[0].centroid.xy, c='black')
ax.plot(*shapely.ops.unary_union(oakland_map.loc[0].geometry).exterior.xy)
area_overlap(oakland_1940.loc[(oakland_1940.GISJOIN == 'G06000100041')].polygonized.values[0], 
            shapely.ops.unary_union(oakland_map.loc[0].polygonized))
# Out:
# 0.4576433005538405

# %%
def get_city_data(city_name):
    """
    Pull city redlining map and census tract map.
    """
    # get map and census data
    city_filename = str(cities[cities.city == city_name].filename.values[0])
    print(city_filename)
    city_map = gpd.read_file(MAP_FILEPATH + city_filename)
    state_fips = str(cities[cities.city == city_name].state.values[0])
    county_fips = str(cities[cities.city == city_name].county.values[0])
    if county_fips == '121': # special case: atlanta has 2 counties in metro area covered in redlining map
        city_1940 = tracts_1940.loc[(tracts_1940.STATE == state_fips) 
                                    & ((tracts_1940.COUNTY == county_fips) | (tracts_1940.COUNTY == '089'))]
    else:
        city_1940 = tracts_1940.loc[(tracts_1940.STATE == state_fips) & (tracts_1940.COUNTY == county_fips)]

    # match crs to tract map
    city_map = city_map.to_crs(city_1940.crs)
    
    city_1940 = city_1940.filter(['GISJOIN', 'geometry'])
    city_1940['polygonized'] = polygonize(city_1940.geometry)
    city_map['polygonized'] = polygonize(city_map.geometry)
#     city_map.plot()
#     city_1940.head()
    return city_map, city_1940

# %%
for i in range(len(cities.index)):
    city_map, city_1940 = get_city_data(cities.loc[i].city)
    generate_crosswalk(cities.loc[i].city, city_map, city_1940)
# Out:
#   0%|          | 0/117 [00:00<?, ?it/s]
# CAOakland1937.geojson
# ...
#   0%|          | 0/111 [00:00<?, ?it/s]
# For Oakland, 53.800000000000004% districts had one or more matching 1940 tracts.
# GAAtlanta1938.geojson
# 100%|██████████| 111/111 [00:03<00:00, 34.38it/s]
# For Atlanta, 31.5% districts had one or more matching 1940 tracts.
# ILChicago1940.geojson
# ...
#   0%|          | 0/157 [00:00<?, ?it/s]
# For Chicago, 40.5% districts had one or more matching 1940 tracts.
# MDBaltimore1937.geojson
#  82%|████████▏ | 128/157 [00:01<00:00, 61.40it/s]TopologyException: Input geom 0 is invalid: Ring Self-intersection at or near point 1650263.442400001 369726.14250000007 at 1650263.442400001 369726.14250000007
# TopologyException: Input geom 0 is invalid: Ring Self-intersection at or near point 1650263.442400001 369726.14250000007 at 1650263.442400001 369726.14250000007
# ...
#   0%|          | 0/451 [00:00<?, ?it/s]
# For Baltimore, 50.8% districts had one or more matching 1940 tracts.
# ...
